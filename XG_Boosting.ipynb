# %%
#Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Mounting
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
#Packages
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
import xgboost as xgb
from sklearn.tree import DecisionTreeClassifier

# %%
#Importing Data
df=pd.read_csv("/content/drive/MyDrive/PokemonDT.csv")
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Label Encoder

# %%
encoder=LabelEncoder()

# %%
for x in df.columns:
  if df[x].dtype=="object":
    df[x]=encoder.fit_transform(df[x])

# %%
df.head()
# Out:
#    #  Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1    42       9      13    318  45      49       49       65       65
# 1  2   166       9      13    405  60      62       63       80       80
# 2  3   379       9      13    525  80      82       83      100      100
# 3  3   380       9      13    625  80     100      123      122      120
# 6  6    52       6       7    534  78      84       78      109       85
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 6    100           1      False

# %%
x=df.drop("Legendary",axis=1)
y=df["Legendary"]

# %%
x
# Out:
#        #  Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1    42       9      13    318  45      49       49       65       65
# 1      2   166       9      13    405  60      62       63       80       80
# 2      3   379       9      13    525  80      82       83      100      100
# 3      3   380       9      13    625  80     100      123      122      120
# 6      6    52       6       7    534  78      84       78      109       85
# ..   ...   ...     ...     ...    ...  ..     ...      ...      ...      ...
# 795  719    78      15       4    600  50     100      150      100      150
# 796  719    79      15       4    700  50     160      110      160      110
# 797  720   155      14       8    600  80     110       60      150      130
# 798  720   156      14       1    680  80     160       60      170      130
# 799  721   388       6      17    600  80     110      120      130       90
#
#      Speed  Generation
# ...

# %%
y
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 6      False
#        ...
# 795     True
# 796     True
# 797     True
# 798     True
# 799     True
# Name: Legendary, Length: 414, dtype: bool

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# Model Building

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=model.predict(x_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.9156626506024096

# %% [markdown]
# Hyper-parameter

# %%
params = {
    "criterion" : ["gini", "entropy"],
    "max_depth": [3, 4, 5, 6],
    "min_samples_split" : [4, 5, 6, 7]
}

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=model.predict(x_test)

# %%
grid=GridSearchCV(model,param_grid=params,cv=4,verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 4 folds for each of 32 candidates, totalling 128 fits
# [CV 1/4] END criterion=gini, max_depth=3, min_samples_split=4;, score=0.940 total time=   0.0s
# [CV 2/4] END criterion=gini, max_depth=3, min_samples_split=4;, score=0.976 total time=   0.0s
# [CV 3/4] END criterion=gini, max_depth=3, min_samples_split=4;, score=0.952 total time=   0.0s
# [CV 4/4] END criterion=gini, max_depth=3, min_samples_split=4;, score=0.939 total time=   0.0s
# [CV 1/4] END criterion=gini, max_depth=3, min_samples_split=5;, score=0.940 total time=   0.0s
# [CV 2/4] END criterion=gini, max_depth=3, min_samples_split=5;, score=0.976 total time=   0.0s
# [CV 3/4] END criterion=gini, max_depth=3, min_samples_split=5;, score=0.952 total time=   0.0s
# [CV 4/4] END criterion=gini, max_depth=3, min_samples_split=5;, score=0.939 total time=   0.0s
# [CV 1/4] END criterion=gini, max_depth=3, min_samples_split=6;, score=0.940 total time=   0.0s
# ...

# %%
model_best=grid.best_estimator_

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 4}

# %%
pred=model_best.predict(x_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.9156626506024096

# %%
model=DecisionTreeClassifier(criterion="gini",max_depth=4,min_samples_split=4)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_split=4)

# %%
pred1=model.predict(x_test)

# %%
accuracy_score(y_test, pred1)
# Out:
# 0.9397590361445783

# %% [markdown]
# XG Boosting

# %%
from xgboost import XGBClassifier as XGB

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier as XGB

# %%
df1=pd.read_csv('/content/drive/MyDrive/diabetes.csv')
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
encoder = LabelEncoder()

for x in df.columns:
  if df[x].dtype == "object":
    df[x] = encoder.fit_transform(df[x])

# %%
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# features
x = df1.drop("Outcome", axis = 1)

# target
y = df1["Outcome"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 45)

# %%
models=[]

models.append(("LR", LogisticRegression()))
models.append(("DT", DecisionTreeClassifier()))
models.append(("RF", RandomForestClassifier()))
models.append(("XGB", XGB()))

# %%
results=[]

names=[]

for name, model in models:
  model.fit(x_train, y_train)
  y_pred = model.predict(x_test)
  print(f"Acc for {name} is {accuracy_score(y_test,y_pred)}")
# Out:
# Acc for LR is 0.7186147186147186
# Acc for DT is 0.6666666666666666
# Acc for RF is 0.7575757575757576
# Acc for XGB is 0.7142857142857143

# %%
models.clear()

# %%
#Iteration 2

# %%
models = []

models.append(("LR", LogisticRegression()))
models.append(("DT", DecisionTreeClassifier()))
models.append(("RF", RandomForestClassifier()))
models.append(("XGB", XGB(eta=0.01)))

# %%
results = []


names = []

for name, model in models:
  model.fit(x_train, y_train)
  pred = model.predict(x_test)

  print(f"Acc for {name} is {accuracy_score(y_test, pred)}")
# Out:
# Acc for LR is 0.7186147186147186
# Acc for DT is 0.6666666666666666
# Acc for RF is 0.7359307359307359
# Acc for XGB is 0.7402597402597403

# %%
models = []

models.append(("LR", LogisticRegression()))
models.append(("DT", DecisionTreeClassifier()))
models.append(("RF", RandomForestClassifier()))
models.append(("XGB", XGB(eta=0.05)))

# %%
results = []


names = []

for name, model in models:
  model.fit(x_train, y_train)
  pred = model.predict(x_test)

  print(f"Acc for {name} is {accuracy_score(y_test, pred)}")
# Out:
# Acc for LR is 0.7186147186147186
# Acc for DT is 0.683982683982684
# Acc for RF is 0.7445887445887446
# Acc for XGB is 0.7445887445887446

# %%
models.clear()

# %%
models = []

models.append(("Logistic Regression", LogisticRegression()))
models.append(("Decision Tree", DecisionTreeClassifier()))
models.append(("RFC", RandomForestClassifier()))
models.append(("XGBn", XGB(gamma = 50)))

# %%
results = []


names = []

for name, model in models:
  model.fit(x_train, y_train)
  pred = model.predict(x_test)

  print(f"Acc for {name} is {accuracy_score(y_test, pred)}")
# Out:
# Acc for Logistic Regression is 0.7186147186147186
# Acc for Decision Tree is 0.6753246753246753
# Acc for RFC is 0.7445887445887446
# Acc for XGBn is 0.7316017316017316

# %%
models.clear()

# %%
models = []

models.append(("Logistic Regression", LogisticRegression()))
models.append(("Decision Tree", DecisionTreeClassifier()))
models.append(("RFC", RandomForestClassifier()))
models.append(("XGBn", XGB(eta = 0.05, gamma = 50)))

# %%
results = []


names = []

for name, model in models:
  model.fit(x_train, y_train)
  pred = model.predict(x_test)

  print(f"Acc for {name} is {accuracy_score(y_test, pred)}")
# Out:
# Acc for Logistic Regression is 0.7186147186147186
# Acc for Decision Tree is 0.6623376623376623
# Acc for RFC is 0.7402597402597403
# Acc for XGBn is 0.7316017316017316

# %%
models.clear()

# %%
params = {
    "gamma" : [90, 30, 40, 50],
    "eta": [0.01, 0.02, 0.05, 0.08, 0.1, 0.5]
}

# %%
xgb_model = XGB()

# %%
grid_xg=GridSearchCV(xgb_model,param_grid=params,cv=4,verbose=3)

# %%
grid_xg.fit(x_train,y_train)
# Out:
# Fitting 4 folds for each of 24 candidates, totalling 96 fits
# [CV 1/4] END ................eta=0.01, gamma=90;, score=0.644 total time=   0.1s
# [CV 2/4] END ................eta=0.01, gamma=90;, score=0.649 total time=   0.1s
# [CV 3/4] END ................eta=0.01, gamma=90;, score=0.642 total time=   0.1s
# [CV 4/4] END ................eta=0.01, gamma=90;, score=0.642 total time=   0.1s
# [CV 1/4] END ................eta=0.01, gamma=30;, score=0.644 total time=   0.1s
# [CV 2/4] END ................eta=0.01, gamma=30;, score=0.731 total time=   0.2s
# [CV 3/4] END ................eta=0.01, gamma=30;, score=0.739 total time=   0.1s
# [CV 4/4] END ................eta=0.01, gamma=30;, score=0.724 total time=   0.2s
# [CV 1/4] END ................eta=0.01, gamma=40;, score=0.644 total time=   0.2s
# [CV 2/4] END ................eta=0.01, gamma=40;, score=0.649 total time=   0.2s
# [CV 3/4] END ................eta=0.01, gamma=40;, score=0.739 total time=   0.2s
# ...

# %%
grid_xg.best_params_
# Out:
# {'eta': 0.5, 'gamma': 40}

# %%
grid_xg.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.5, eval_metric=None,
#               feature_types=None, gamma=40, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
pred2=grid_xg.predict(x_test)

# %%
print(f"Acc for {accuracy_score(y_test, pred2)}")
# Out:
# Acc for 0.7316017316017316
